# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import pathlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_dir = pathlib.Path('dataset')
batch_size = 110
image_height = 216
image_width = 216

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.1, 
    subset="training",
    seed=123,
    image_size=(image_height, image_width),
    batch_size=batch_size)


validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.1,
    subset="validation", 
    seed=123,
    image_size=(image_height, image_width),
    batch_size=batch_size)
# Out:
# Found 3929 files belonging to 10 classes.
# Using 3537 files for training.
# Found 3929 files belonging to 10 classes.
# Using 392 files for validation.

# %%
class_names = train_ds.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
num_classes = 10
model = Sequential([
    layers.Rescaling(1./255, input_shape=(image_height, image_width, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)    
])
# Out:
# C:\Users\tsjdu\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
epochs=35
history=model.fit(train_ds, validation_data=validation_ds, epochs=epochs)
# Out:
# Epoch 1/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 520ms/step - accuracy: 0.1051 - loss: 9.2805 - val_accuracy: 0.0969 - val_loss: 8.8718
# Epoch 2/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 512ms/step - accuracy: 0.1147 - loss: 8.3658 - val_accuracy: 0.1224 - val_loss: 2.3026
# Epoch 3/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 536ms/step - accuracy: 0.1414 - loss: 2.3172 - val_accuracy: 0.1224 - val_loss: 2.3295
# Epoch 4/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 562ms/step - accuracy: 0.1163 - loss: 2.3187 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 5/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 520ms/step - accuracy: 0.1131 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 6/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.1196 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 7/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 504ms/step - accuracy: 0.1159 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 8/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 469ms/step - accuracy: 0.1168 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 9/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 478ms/step - accuracy: 0.1138 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 10/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 505ms/step - accuracy: 0.1094 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 11/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 477ms/step - accuracy: 0.1167 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 12/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 584ms/step - accuracy: 0.1104 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 13/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 497ms/step - accuracy: 0.1136 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 14/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 532ms/step - accuracy: 0.1120 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 15/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 560ms/step - accuracy: 0.1188 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 16/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 504ms/step - accuracy: 0.1181 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 17/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 485ms/step - accuracy: 0.1107 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 18/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 491ms/step - accuracy: 0.1158 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 19/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 508ms/step - accuracy: 0.1172 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 20/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 538ms/step - accuracy: 0.1116 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 21/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 553ms/step - accuracy: 0.1171 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 22/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 17s 517ms/step - accuracy: 0.1176 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 23/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 465ms/step - accuracy: 0.1158 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 24/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.1142 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 25/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 475ms/step - accuracy: 0.1150 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 26/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 461ms/step - accuracy: 0.1135 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 27/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 465ms/step - accuracy: 0.1118 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 28/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 15s 462ms/step - accuracy: 0.1157 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 29/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 469ms/step - accuracy: 0.1118 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 30/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 470ms/step - accuracy: 0.1145 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 31/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.1111 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 32/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.1135 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 33/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.1170 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 34/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 483ms/step - accuracy: 0.1204 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026
# Epoch 35/35
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 16s 469ms/step - accuracy: 0.1135 - loss: 2.3026 - val_accuracy: 0.1250 - val_loss: 2.3026

# %%
accuracy = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)
plt.figure(figsize=(8, 8))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
test_dir = pathlib.Path('test-images')
test_paths = list(test_dir.glob('*.jpg'))
class_names = ['Australian terrier', 'Beagle', 'Border terrier', 'Dingo', 'English foxhound', 'Golden retriever', 'English sheepdog', 'Rhodesian ridgeback', 'Samoyed', 'Shih-Tzu']

plt.figure(figsize=(10, 10))

for i, test_path in enumerate(test_paths):
    test_img = keras.preprocessing.image.load_img(test_path, target_size=(216, 216))
    img_arr = keras.preprocessing.image.img_to_array(test_img)
    img_arr = tf.expand_dims(img_arr, 0)
    
    predictions = model.predict(img_arr)
    
    predicted_class = np.argmax(predictions)
    
    score = tf.nn.softmax(predictions[0])
    percent = int(round(100*np.max(score), 0))
    title = "{} - {} %".format(class_names[predicted_class], percent)
    
    ax = plt.subplot(4, 3, i + 1)
    plt.imshow(dino_img)
    plt.title(title)
    plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
